# %% [markdown]
# <a href="https://colab.research.google.com/github/angjennfang/my-learning-journal/blob/main/First%20Use%20of%20Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello from Colab!")
# Out:
# Hello from Colab!

# %%
input("What is your name")
# Out:
# Wahat is your nameAng Jenn Fang
# 'Ang Jenn Fang'
